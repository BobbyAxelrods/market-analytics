# %% [markdown]
# # 1.0 Get the raw content

# %%
import requests
import pandas as pd
import os
import sys

# %%
from bs4 import BeautifulSoup

# %%
import csv

# %%
URL = 'https://verifiedinvestingcrypto.com/'
r = requests.get(URL)
print(r.content)
# Out:
# b'<!DOCTYPE html>\n<html lang="en-US" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">\n<head>\n<meta charset="UTF-8">\n<link rel="profile" href="https://gmpg.org/xfn/11">\n<meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' />\n<meta name="viewport" content="width=device-width, initial-scale=1">\n\n<title>Verified Investing Crypto Home - Verified Investing Crypto</title>\n<meta name="description" content="A service dedicated to live crypto trades, daily videos with technical analysis, cycles and education and more." />\n<link rel="canonical" href="https://verifiedinvestingcrypto.com/" />\n<meta property="og:locale" content="en_US" />\n<meta property="og:type" content="website" />\n<meta property="og:title" content="Verified Investing Crypto" />\n<meta property="og:description" content="A service dedicated to live crypto trades, daily videos with technical analysis, cycles and education and more." />\n<meta property="
# ...

# %% [markdown]
# ## 2.0 Parsing the HTML content (table)

# %%
soup = BeautifulSoup(r.content, 'html5lib')
print(soup.prettify())
dfs =
# Out:
# <!DOCTYPE html>
# <html lang="en-US" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://gmpg.org/xfn/11" rel="profile"/>
#   <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Verified Investing Crypto Home - Verified Investing Crypto
#   </title>
#   <meta content="A service dedicated to live crypto trades, daily videos with technical analysis, cycles and education and more." name="description"/>
#   <link href="https://verifiedinvestingcrypto.com/" rel="canonical"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Verified Investing Crypto" property="og:title"/>
# ...

# %% [markdown]
# ## 3.0 Getting the Data & Parsing Header

# %%
 #list to store data
list_header= []
table = soup.find('table').find('tr')

for items in table:
    try:
        list_header.append(items.get_text()) #using beautiful soup get_text()
    except:
        continue

# %% [markdown]
# ## 4.0 Parsing Data Table

# %%
HTML_data = soup.find_all('table')[0].find_all('tr')[1:]

for element in HTML_data:
    sub_data=[]
    for sub_element in element:
        try:
            sub_data.append(sub_element.get_text())
        except:
            continue
    data.append(sub_data)

# %%
dataframe = pd.DataFrame(data=data, columns= list_header)

# %%
dataframe.to_csv('g.csv')

# %%
df = pd.read_csv('g.csv')
df_df = pd.DataFrame(df)

# %%
df_df
# Out:
#     Unnamed: 0  \n              Crypto Long/Short  Entry Date  Entry Price  \
# 0            0  \n             SOL/USD        Buy  06/29/2022       $34.10
# 1            1  \n           MATIC/USD        Buy  07/01/2022        $0.45
# 2            2  \n             SOL/USD        Buy  06/08/2022      $35.78*
# 3            3  \n           MATIC/USD        Buy  06/08/2022      $0.449*
# 4            4  \n            LINK/USD        Buy  05/11/2022       $6.80*
# 5            5  \n             ADA/USD        Buy  05/09/2022       $0.53*
# 6            6  \n           MATIC/USD        Buy  05/11/2022       $0.63*
# 7            7  \n             DOT/USD        Buy  05/09/2022       $9.70*
# 8            8  \n            LUNA/USD        Buy  05/09/2022      $42.95*
# 9            9  \n           MATIC/USD        Buy  04/30/2022      $1.025*
# 10          10  \n            AVAX/USD        Buy  04/30/2022      $55.70*
# ...
